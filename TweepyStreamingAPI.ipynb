# %%
#keys taken from twitter developer account
consumer_key = 'STmfnnIiWOKB8S5SENEUAGZAZ'
consumer_secret  = 'uM6gVsNw7qTrpuicXVFx3Vgb8qyA6bdDNpfJhU01oll5bDUnmQ'
access_token = '1102777661523410944-mkT0HKSNzbspAxnfsAPiaM18g8gD9D'
access_secret = 'CiXpgkpHZ0PB6DdvzIAXadjWEPXQta8iCbVPjv5UPVHzv'

# %%
import tweepy
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)
api =tweepy.API(auth)  #tweepy.API(auth,waitonratelimit = True) -To extract more tweets

# %% [markdown]
# # To check followers of a particular person

# %%
followers_status = api.followers('narendramodi',count=200)
len(followers_status)
# Out:
# 200

# %%
users = api.search_users('chowkidar',count=200)
len(users)
# Out:
# 20

# %%
# to check limits for various queries
api.rate_limit_status()
# Out:
# {'rate_limit_context': {'access_token': '1102777661523410944-mkT0HKSNzbspAxnfsAPiaM18g8gD9D'},
#  'resources': {'lists': {'/lists/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554182401},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1554182401},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554182401},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1554182401},
#    '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1554182401},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1554182401},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1554182401},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1554182401},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1554182401},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1554182401}},
# ...

# %%
import os
os.getcwd()
# Out:
# 'D:\\Manipal Pro learn\\Term1\\DataScrapping\\Programming'

# %%
import glob
import pandas as pd
glob.glob('*.csv')
# Out:
# []

# %% [markdown]
# # 'tweets_datascience.csv' is created by listening to onlineStreaming of twitter using 'twitter_streaming.py'
#
# ![image.png](attachment:image.png)

# %%
file_name = 'tweets_datascience.csv'
file_exists = file_name in glob.glob('*.csv')
file_exists
# Out:
# False

# %%
file_name = 'temp.csv'
file_exists = file_name in glob.glob('*.csv')

df = pd.DataFrame({'x':[1,2,3],'y':[4,5,6]})

if file_exists:
    with open(file_name,'a') as f:
        df.to_csv(f,index=False, header=False) # only for first time header(column names) should be added
else:
    df.to_csv(file_name,index=False)

# %%
pd.read_csv(file_name)
# Out:
#    x  y
# 0  1  4
# 1  2  5
# 2  3  6
# 3  1  4
# 4  2  5
# 5  3  6
